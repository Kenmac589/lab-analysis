# %%
import numpy as np
from pyomeca import Analogs
import matplotlib.pyplot as plt

muscles = [
    "GM",
    "Ip",
    "BF",
    "VL",
    "St",
    "TA",
    "Gs",
    "Gr"
]

# Load Data

data_path = "./CoM-M3-WT-20220420-3.csv"
emg = Analogs.from_csv(data_path, header=0, time_column=0, first_row=1, first_column=1)

# Plot EMG
emg.plot(x="time", col="channel", col_wrap=3)
plt.show()

# Proccessing the EMG
emg_processed = (
    emg.meca.band_pass(order=2, cutoff=[30, 425])
    .meca.center()
    .meca.abs()
    .meca.low_pass(order=4, cutoff=5, freq=emg.rate)
    .meca.normalize()
)
fig, axes = plt.subplots(ncols=2, figsize=(10, 4))

emg_processed.mean("channel").plot(ax=axes[0])
axes[0].set_title("Mean EMG activation")

emg_processed.plot.hist(ax=axes[1], bins=50)
axes[1].set_title("EMG activation distribution")
emg_processed.plot(x="time", col="channel", col_wrap=3)

emg_processed.name = "EMG"
emg_processed.attrs["units"] = "%"
emg_processed.time.attrs["units"] = "seconds"

emg_processed.plot(x="time", col="channel", col_wrap=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 27
#      23 plt.show()
#      25 # Proccessing the EMG
#      26 emg_processed = (
# ---> 27     emg.meca.band_pass(order=2, cutoff=[30, 425])
#      28     .meca.center()
#      29     .meca.abs()
#      30     .meca.low_pass(order=4, cutoff=5, freq=emg.rate)
#      31     .meca.normalize()
#      32 )
#      33 fig, axes = plt.subplots(ncols=2, figsize=(10, 4))
#      35 emg_processed.mean("channel").plot(ax=axes[0])
#
# File ~/miniconda/lib/python3.9/site-packages/pyomeca/dataarray_accessor.py:560, in DataArrayAccessor.band_pass(self, order, cutoff, freq)
#     520 def band_pass(
#     521     self,
#     522     order: int,
#     523     cutoff: Union[list, tuple, np.array],
#     524     freq: Optional[Union[int, float]] = None,
#     525 ) -> xr.DataArray:
#     526     """
#     527     Band-pass Butterworth filter.
#     528
#    (...)
#     558         ![band_pass](/images/api/band_pass.svg)
#     559     """
# --> 560     return filter.band_pass(self._obj, order, cutoff, freq)
#
# File ~/miniconda/lib/python3.9/site-packages/pyomeca/processing/filter.py:52, in band_pass(array, order, cutoff, freq)
#      46 def band_pass(
#      47     array: xr.DataArray,
#      48     order: int,
#      49     cutoff: Union[list, tuple, np.array],
#      50     freq: Optional[Union[int, float]] = None,
#      51 ) -> xr.DataArray:
# ---> 52     return _base_filter(array, order, cutoff, freq, btype="bandpass")
#
# File ~/miniconda/lib/python3.9/site-packages/pyomeca/processing/filter.py:19, in _base_filter(array, order, cutoff, freq, btype)
#      17         freq = array.rate
#      18     else:
# ---> 19         raise ValueError(
#      20             "the `freq` param is optional only if `rate` is available in the attrs dictionnary (array.attrs`)"
#      21         )
#      22 nyquist = freq / 2
#      23 corrected_freq = np.array(cutoff) / nyquist
#
# ValueError: the `freq` param is optional only if `rate` is available in the attrs dictionnary (array.attrs`)
